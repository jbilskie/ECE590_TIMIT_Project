# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import imageio
import scipy
from sklearn import preprocessing
from scipy import signal
import timit_utils as tu
import timit_utils.audio_utils as au
import timit_utils.drawing_utils as du
import librosa
import pywt
import random

corpus = tu.Corpus('TIMIT')
train = corpus.train
test = corpus.test
corpus.train, corpus.test
# Out:
# (<timit_utils.core.SubCorpus at 0x1e2e2720390>,
#  <timit_utils.core.SubCorpus at 0x1e2e9ee9d68>)

# %% [markdown]
# ### Split sentences into training and testing data

# %%
data_set = []
label_id = []
label_gen = []
label_dem = []
for p in range(len(train.people)):
    count = 0
    for s in range(len(train.person_by_index(p).sentences)):
        sentence = train.person_by_index(p).sentence_by_index(s).raw_audio
        data_set.append(sentence)
        label_id.append(train.person_by_index(p).name)
        label_gen.append(train.person_by_index(p).gender)
        label_dem.append(train.person_by_index(p).region_name)
for p in range(len(test.people)):
    count = 0
    for s in range(len(test.person_by_index(p).sentences)):
        sentence = test.person_by_index(p).sentence_by_index(s).raw_audio
        data_set.append(sentence)
        label_id.append(test.person_by_index(p).name)
        label_gen.append(test.person_by_index(p).gender)
        label_dem.append(test.person_by_index(p).region_name)
num_speakers = len(set(label_id))
print('Number of speakers in data: ', num_speakers)
# Out:
# Number of speakers in data:  630

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(label_id)
label_id = le1.transform(label_id)
le2 = preprocessing.LabelEncoder()
le2.fit(label_gen)
label_gen = le2.transform(label_gen)
le3 = preprocessing.LabelEncoder()
le3.fit(label_dem)
label_dem = le3.transform(label_dem)

N = 20 # number of speakers being considered
sub_data_set = []
sub_label_id = []
sub_label_gen = []
sub_label_dem = []
speak_ind = []
for ind1 in range(N):
    ind2 = np.random.randint(630, size=1)
    while ind2[0] in speak_ind is False:
        ind2 = np.random.randint(630, size=1)
    speak_ind.append(ind2[0])
act_ind = []
for ID in speak_ind:
    act_ind= np.where(label_id == ID)
    sub_data_set = sub_data_set+data_set[act_ind[0][0]:act_ind[0][-1]+1]
    sub_label_id = sub_label_id+label_id[act_ind[0]].tolist()
    sub_label_gen = sub_label_gen+label_gen[act_ind[0]].tolist()
    sub_label_dem = sub_label_dem+label_dem[act_ind[0]].tolist()

# %%
sentence_lengths = []
for p in range(len(train.people)):
    for s in range(len(train.person_by_index(p).sentences)):
        sentence_lengths.append(len(train.person_by_index(p).sentence_by_index(s).raw_audio))
for p in range(len(test.people)):
    for s in range(len(test.person_by_index(p).sentences)):
        sentence_lengths.append(len(test.person_by_index(p).sentence_by_index(s).raw_audio))

# %%
fs = 16000
wlen = 0.02
num_train_per_test = 3 # for every 3 training sentences, there is 1 testing sentence
training_set = []
training_label_id = []
training_label_gen = []
training_label_dem = []
testing_set = []
testing_label_id = []
testing_label_gen = []
testing_label_dem = []
for ID in set(sub_label_id):
    person_ind = [i for i, x in enumerate(sub_label_id) if x == ID]
    for i, sent_per_ID in enumerate(person_ind):
        if i%(num_train_per_test+1) == 0:
            testing_set.append(sub_data_set[sent_per_ID])
            testing_label_id.append(sub_label_id[sent_per_ID])
            testing_label_gen.append(sub_label_gen[sent_per_ID])
            testing_label_dem.append(sub_label_dem[sent_per_ID])
        else:
            training_set.append(sub_data_set[sent_per_ID])
            training_label_id.append(sub_label_id[sent_per_ID])
            training_label_gen.append(sub_label_gen[sent_per_ID])
            training_label_dem.append(sub_label_dem[sent_per_ID])

len_samps = 1 # length of samples in seconds
ave_seconds_per_ID = sum(sentence_lengths)/(fs*len(sentence_lengths))*10
num_samps_per_ID = round(ave_seconds_per_ID)*5
num_samps_per_ID_test = round(num_samps_per_ID*(1/(num_train_per_test+1)))
num_samps_per_ID_train = num_samps_per_ID-num_samps_per_ID_test
training_data = []
training_l_id = []
training_l_gen = []
training_l_dem = []
testing_data = []
testing_l_id = []
testing_l_gen = []
testing_l_dem = []
for ID_i, ID in enumerate(set(sub_label_id)):
    train_person_ind = [i for i, x in enumerate(training_label_id) if x == ID]
    test_person_ind = [i for i, x in enumerate(testing_label_id) if x == ID]
    for samp in range(num_samps_per_ID_train):
        sent = random.choice(train_person_ind)
        while len(training_set[sent]) < round(fs*len_samps):
            sent = random.choice(train_person_ind)
        start_i = random.randint(0,len(training_set[sent])-round(fs*len_samps))
        training_data.append(training_set[sent][start_i:start_i+round(fs*len_samps)])
        training_l_id.append(ID_i)
        training_l_gen.append(training_label_gen[sent])
        training_l_dem.append(training_label_dem[sent])
    for samp in range(num_samps_per_ID_test):
        sent = random.choice(test_person_ind)
        while len(testing_set[sent]) < round(fs*len_samps):
            sent = random.choice(test_person_ind)
        start_i = random.randint(0,len(testing_set[sent])-round(fs*len_samps))
        testing_data.append(testing_set[sent][start_i:start_i+round(fs*len_samps)])
        testing_l_id.append(ID_i)
        testing_l_gen.append(testing_label_gen[sent])
        testing_l_dem.append(testing_label_dem[sent])

# %%
# Use spectrogram from Librosa
plt.title('Librose Spectrogram of Training Speech Sample')
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
S = librosa.feature.chroma_stft(y=training_data[0], sr=16000, n_fft=1024, hop_length=160, n_chroma=128)
S = S/np.amax(S)
plt.contourf(20*np.log10(S),100,cmap='jet')
plt.colorbar()
plt.show()
print('Size of spectrogram is: ', np.shape(S))
# Out:
# Size of spectrogram is:  (128, 101)

# %%
# Use spectrogram from Librosa
plt.title('Librose Spectrogram of Training Speech Sample')
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
S = librosa.feature.melspectrogram(y=training_data[0], sr=16000, n_fft=1024, hop_length=160)
S = S/np.amax(S)
plt.contourf(20*np.log10(S),100,cmap='jet')
plt.colorbar()
plt.show()
print('Size of spectrogram is: ', np.shape(S))
# Out:
# Size of spectrogram is:  (128, 101)

# %%
# Use spectrogram from Librosa
plt.title('Librose Spectrogram of Training Speech Sample')
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
S = librosa.core.stft(y=training_data[0], n_fft=256, hop_length=160)
S = abs(S)/abs(np.amax(S))
plt.contourf(20*np.log10(S),100,cmap='jet')
plt.colorbar()
plt.show()
print('Size of spectrogram is: ', np.shape(S))
# Out:
# Size of spectrogram is:  (129, 101)

# %% [markdown]
# ### Train & test model

# %%
batch_size = 5
train_loader,test_loader = {},{}
train_list = []
for ind, data in enumerate(training_data):
    S = librosa.feature.melspectrogram(y=training_data[ind], sr=16000, n_fft=1024, hop_length=160)
    S = S/np.amax(S)
    train_list.append((20*np.log10(abs(S)), training_l_id[ind], training_l_gen[ind], training_l_dem[ind]))
test_list = []
for ind, data in enumerate(testing_data):
    S = librosa.feature.melspectrogram(y=testing_data[ind], sr=16000, n_fft=1024, hop_length=160)
    S = S/np.amax(S)
    test_list.append((20*np.log10(abs(S)), testing_l_id[ind], testing_l_gen[ind], testing_l_dem[ind]))
train_loader['timit'] = torch.utils.data.DataLoader(train_list, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader['timit'] = torch.utils.data.DataLoader(test_list, batch_size=batch_size, shuffle=True, num_workers=0)
print('Done with calculating spectrograms.')
# Out:
# Done with calculating spectrograms.

# %%
class LeNet5(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=30, kernel_size=3, stride=1)
        self.conv2 = nn.Conv2d(in_channels=30, out_channels=15, kernel_size=3, stride=1)
        self.fc1   = nn.Linear(in_features=15*30*23, out_features=200)
        self.drop1 = nn.Dropout(p=0.5, inplace=False)
        self.fc3_1   = nn.Linear(in_features=200, out_features=out_channels)
        self.fc3_2   = nn.Linear(in_features=200, out_features=out_channels)
        self.fc3_3   = nn.Linear(in_features=200, out_features=out_channels)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x),0)
        x = F.max_pool2d(x, 2)
        x = F.leaky_relu(self.conv2(x),0)
        x = F.max_pool2d(x, 2)
        x = x.view(x.size(0), -1) # flattens
        x = F.leaky_relu(self.fc1(x),0)
        x = self.drop1(x)
        x1 = F.softmax(self.fc3_1(x),dim=0)
        x2 = F.softmax(self.fc3_2(x),dim=0)
        x3 = F.softmax(self.fc3_3(x),dim=0)
        return x1, x2, x3

# %%
def train(model, device, train_loader, criterion, optimizer, epoch):
    train_loss = 0
    model.train()
    model.double()
    for batch_idx, (data, target1, target2, target3) in enumerate(train_loader):
        data, target1, target2, target3=data.to(device), target1.to(device), target2.to(device), target3.to(device)
        data = data.reshape(len(data),1,data[0].size()[0],data[0].size()[1])
        optimizer.zero_grad()
        output1, output2, output3 = model(data)
        loss = (0.9*criterion(output1, target1))+(0.05*criterion(output2, target2))+(0.05*criterion(output3, target3)) 
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        if batch_idx % (len(train_loader)//2) == 0:
            print('Train({})[{:.0f}%]: Loss: {:.4f}'.format(
                epoch, 100. * batch_idx / len(train_loader), train_loss/(batch_idx+1)))

def test(model, device, test_loader, criterion, epoch):
    model.eval()
    model.double()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target1, target2, target3 in test_loader:
            data, target1, target2, target3=data.to(device), target1.to(device), target2.to(device), target3.to(device)
            data = data.reshape(len(data),1,data[0].size()[0],data[0].size()[1])
            output1, output2, output3 = model(data)
            test_loss += criterion(output1, target1).item() # sum up batch loss
            pred = output1.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            #print(target)
            #print(pred)
            correct += pred.eq(target1.view_as(pred)).sum().item()

    test_loss = (test_loss*batch_size)/len(test_loader.dataset)
    print('Test({}): Loss: {:.4f}, Accuracy: {:.4f}%'.format(
        epoch, test_loss, 100. * correct / len(test_loader.dataset)))

# %%
def make_optimizer(optimizer_name, model, **kwargs):
    if optimizer_name=='Adam':
        optimizer = optim.Adam(model.parameters(),lr=kwargs['lr'])
    elif optimizer_name=='SGD':
        optimizer = optim.SGD(model.parameters(),lr=kwargs['lr'],momentum=kwargs['momentum'], weight_decay=kwargs['weight_decay'],nesterov=True)
    else:
        raise ValueError('Not valid optimizer name')
    return optimizer
    
def make_scheduler(scheduler_name, optimizer, **kwargs):
    if scheduler_name=='MultiStepLR':
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer,milestones=kwargs['milestones'],gamma=kwargs['factor'])
    else:
        raise ValueError('Not valid scheduler name')
    return scheduler

# %%
seed = 1
device = 'cpu'
data_name = 'timit'
optimizer_name = 'SGD'
scheduler_name = 'MultiStepLR'
num_epochs = 15
lr = 0.001
device = torch.device(device)
torch.manual_seed(1)
in_channels = 1
out_channels = N
model = LeNet5(in_channels, out_channels).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = make_optimizer(optimizer_name, model, lr=lr, momentum=0.5, weight_decay=0)
scheduler = make_scheduler(scheduler_name, optimizer, milestones=[5,10,15], factor=0.1)
for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader[data_name], criterion, optimizer, epoch)
    test(model, device, test_loader[data_name], criterion, epoch)
    scheduler.step()
    print('Optimizer Learning rate: {0:.4f}'.format(optimizer.param_groups[0]['lr']))
# Out:
# Train(1)[0%]: Loss: 3.0183
# Train(1)[50%]: Loss: 3.0058
# Train(1)[100%]: Loss: 2.9730
# Test(1): Loss: 2.8426, Accuracy: 20.1080%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 2.8441
# Train(2)[50%]: Loss: 2.8632
# Train(2)[100%]: Loss: 2.8427
# Test(2): Loss: 2.7696, Accuracy: 19.7031%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 2.9265
# Train(3)[50%]: Loss: 2.7740
# Train(3)[100%]: Loss: 2.7568
# Test(3): Loss: 2.6802, Accuracy: 31.4440%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 2.7133
# Train(4)[50%]: Loss: 2.7061
# Train(4)[100%]: Loss: 2.6848
# Test(4): Loss: 2.6629, Accuracy: 33.0634%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 2.7173
# Train(5)[50%]: Loss: 2.6050
# Train(5)[100%]: Loss: 2.6001
# Test(5): Loss: 2.5173, Accuracy: 47.6383%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 2.3684
# Train(6)[50%]: Loss: 2.5611
# Train(6)[100%]: Loss: 2.5508
# Test(6): Loss: 2.4985, Accuracy: 50.4723%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 2.6553
# Train(7)[50%]: Loss: 2.5250
# Train(7)[100%]: Loss: 2.5175
# Test(7): Loss: 2.5024, Accuracy: 55.0607%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.6007
# Train(8)[50%]: Loss: 2.5151
# Train(8)[100%]: Loss: 2.5120
# Test(8): Loss: 2.4995, Accuracy: 53.4413%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.5011
# Train(9)[50%]: Loss: 2.5052
# Train(9)[100%]: Loss: 2.5002
# Test(9): Loss: 2.5030, Accuracy: 52.2267%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 2.5741
# Train(10)[50%]: Loss: 2.4871
# Train(10)[100%]: Loss: 2.4998
# Test(10): Loss: 2.4864, Accuracy: 56.6802%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.3399
# Train(11)[50%]: Loss: 2.5046
# Train(11)[100%]: Loss: 2.4993
# Test(11): Loss: 2.4979, Accuracy: 53.5762%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.6559
# Train(12)[50%]: Loss: 2.4817
# Train(12)[100%]: Loss: 2.4992
# Test(12): Loss: 2.4968, Accuracy: 55.0607%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.3958
# Train(13)[50%]: Loss: 2.4865
# Train(13)[100%]: Loss: 2.4928
# Test(13): Loss: 2.4836, Accuracy: 56.2753%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.3923
# Train(14)[50%]: Loss: 2.5106
# Train(14)[100%]: Loss: 2.5071
# Test(14): Loss: 2.4900, Accuracy: 55.8704%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.4020
# Train(15)[50%]: Loss: 2.4897
# Train(15)[100%]: Loss: 2.4955
# Test(15): Loss: 2.4820, Accuracy: 56.1404%
# Optimizer Learning rate: 0.0000

# %%
d = testing_data[0]
S = librosa.core.stft(y=d, n_fft=256, hop_length=160)
S = abs(S)/abs(np.amax(S))
plt.contourf(20*np.log10(S),100,cmap='jet')
plt.colorbar()
plt.show()
print('Size of spectrogram is: ', np.shape(S))
# Out:
# Size of spectrogram is:  (129, 101)

# %%
from scipy.signal import butter, lfilter
b, a = butter(10, 4000/(fs/2), btype='low', analog=False)
d = lfilter(b,a,testing_data[0])
S = librosa.core.stft(y=d, n_fft=256, hop_length=160)
S = abs(S)/abs(np.amax(S))
plt.contourf(20*np.log10(S),100,cmap='jet')
plt.colorbar()
plt.show()
print('Size of spectrogram is: ', np.shape(S))
# Out:
# Size of spectrogram is:  (129, 101)

# %%
def test(model, device, test_loader, criterion, epoch):
    model.eval()
    model.double()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target1, target2, target3 in test_loader:
            data, target1, target2, target3=data.to(device), target1.to(device), target2.to(device), target3.to(device)
            data = data.reshape(len(data),1,data[0].size()[0],data[0].size()[1])
            output1, output2, output3 = model(data)
            test_loss += criterion(output1, target1).item() # sum up batch loss
            pred = output1.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            #print(target)
            #print(pred)
            correct += pred.eq(target1.view_as(pred)).sum().item()

    test_loss = (test_loss*batch_size)/len(test_loader.dataset)
    print('Test({}): Loss: {:.4f}, Accuracy: {:.4f}%'.format(
        epoch, test_loss, 100. * correct / len(test_loader.dataset)))
    acc = 100. * correct / len(test_loader.dataset)
    return acc

# %%
cf_array = [200,500,1000,2000,4000,8000]
performances = []
for cf in cf_array:
    perf = []
    print('Cutoff Frequency is {}.'.format(cf))
    batch_size = 5
    train_loader,test_loader = {},{}
    train_list = []
    for ind, data in enumerate(training_data):
        if cf == 8000:
            d = training_data[ind]
        else:
            b, a = butter(10, cf/(fs/2), btype='low', analog=False)
            d = lfilter(b,a,training_data[ind])
        S = librosa.feature.melspectrogram(y=d, sr=16000, n_fft=1024, hop_length=160)
        S = S/np.amax(S)
        train_list.append((20*np.log10(abs(S)), training_l_id[ind], training_l_gen[ind], training_l_dem[ind]))
    test_list = []
    for ind, data in enumerate(testing_data):
        if cf == 8000:
            d = training_data[ind]
        else:
            b, a = butter(10, cf/(fs/2), btype='low', analog=False)
            d = lfilter(b,a,testing_data[ind])
        S = librosa.feature.melspectrogram(y=d, sr=16000, n_fft=1024, hop_length=160)
        S = S/np.amax(S)
        test_list.append((20*np.log10(abs(S)), testing_l_id[ind], testing_l_gen[ind], testing_l_dem[ind]))
    train_loader['timit'] = torch.utils.data.DataLoader(train_list, batch_size=batch_size, shuffle=True, num_workers=0)
    test_loader['timit'] = torch.utils.data.DataLoader(test_list, batch_size=batch_size, shuffle=True, num_workers=0)
    print('Done with calculating spectrograms.')

    seed = 1
    device = 'cpu'
    data_name = 'timit'
    optimizer_name = 'SGD'
    scheduler_name = 'MultiStepLR'
    num_epochs = 15
    lr = 0.001
    device = torch.device(device)
    torch.manual_seed(1)
    in_channels = 1
    out_channels = N
    model = LeNet5(in_channels, out_channels).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = make_optimizer(optimizer_name, model, lr=lr, momentum=0.5, weight_decay=0)
    scheduler = make_scheduler(scheduler_name, optimizer, milestones=[5,10,15], factor=0.1)
    for epoch in range(1, num_epochs + 1):
        train(model, device, train_loader[data_name], criterion, optimizer, epoch)
        l = test(model, device, test_loader[data_name], criterion, epoch)
        perf.append(l)
        scheduler.step()
        print('Optimizer Learning rate: {0:.4f}'.format(optimizer.param_groups[0]['lr']))
    performances.append(perf)
# Out:
# Cutoff Frequency is 200.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 3.0417
# Train(1)[50%]: Loss: 3.0902
# Train(1)[100%]: Loss: 3.0819
# Test(1): Loss: 3.0532, Accuracy: 3.6437%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 3.2568
# Train(2)[50%]: Loss: 3.0971
# Train(2)[100%]: Loss: 3.0867
# Test(2): Loss: 3.0908, Accuracy: 3.9136%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 2.9032
# Train(3)[50%]: Loss: 3.0619
# Train(3)[100%]: Loss: 3.0724
# Test(3): Loss: 3.0913, Accuracy: 4.5884%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 3.2480
# Train(4)[50%]: Loss: 3.0700
# Train(4)[100%]: Loss: 3.0809
# Test(4): Loss: 3.0540, Accuracy: 5.2632%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 3.2858
# Train(5)[50%]: Loss: 3.0744
# Train(5)[100%]: Loss: 3.0692
# Test(5): Loss: 3.0341, Accuracy: 5.8030%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 3.2658
# Train(6)[50%]: Loss: 3.1058
# Train(6)[100%]: Loss: 3.0847
# Test(6): Loss: 3.0445, Accuracy: 3.7787%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 3.0891
# Train(7)[50%]: Loss: 3.0846
# Train(7)[100%]: Loss: 3.0800
# Test(7): Loss: 3.0630, Accuracy: 4.5884%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 3.0839
# Train(8)[50%]: Loss: 3.0836
# Train(8)[100%]: Loss: 3.0866
# Test(8): Loss: 3.0657, Accuracy: 3.6437%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 3.0968
# Train(9)[50%]: Loss: 3.0775
# Train(9)[100%]: Loss: 3.0751
# Test(9): Loss: 3.0844, Accuracy: 2.9690%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 3.0768
# Train(10)[50%]: Loss: 3.0952
# Train(10)[100%]: Loss: 3.0868
# Test(10): Loss: 3.1037, Accuracy: 2.4291%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 3.0812
# Train(11)[50%]: Loss: 3.0907
# Train(11)[100%]: Loss: 3.0852
# Test(11): Loss: 3.0847, Accuracy: 4.1835%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 3.2772
# Train(12)[50%]: Loss: 3.0911
# Train(12)[100%]: Loss: 3.0785
# Test(12): Loss: 3.0841, Accuracy: 2.9690%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.8959
# Train(13)[50%]: Loss: 3.0754
# Train(13)[100%]: Loss: 3.0742
# Test(13): Loss: 3.0866, Accuracy: 4.1835%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 3.0912
# Train(14)[50%]: Loss: 3.0776
# Train(14)[100%]: Loss: 3.0822
# Test(14): Loss: 3.0861, Accuracy: 3.2389%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 3.0774
# Train(15)[50%]: Loss: 3.1007
# Train(15)[100%]: Loss: 3.0871
# Test(15): Loss: 3.0952, Accuracy: 3.1039%
# Optimizer Learning rate: 0.0000
# Cutoff Frequency is 500.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 2.9789
# Train(1)[50%]: Loss: 3.0916
# Train(1)[100%]: Loss: 3.0795
# Test(1): Loss: 3.0241, Accuracy: 4.9933%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 3.2484
# Train(2)[50%]: Loss: 3.0838
# Train(2)[100%]: Loss: 3.0786
# Test(2): Loss: 3.0402, Accuracy: 4.7233%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 3.0563
# Train(3)[50%]: Loss: 3.0651
# Train(3)[100%]: Loss: 3.0710
# Test(3): Loss: 3.0636, Accuracy: 4.7233%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 3.0838
# Train(4)[50%]: Loss: 3.0967
# Train(4)[100%]: Loss: 3.0955
# Test(4): Loss: 3.0828, Accuracy: 2.9690%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 3.0762
# Train(5)[50%]: Loss: 3.0454
# Train(5)[100%]: Loss: 3.0613
# Test(5): Loss: 3.0624, Accuracy: 4.9933%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 3.1355
# Train(6)[50%]: Loss: 3.0954
# Train(6)[100%]: Loss: 3.0826
# Test(6): Loss: 3.0522, Accuracy: 3.7787%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 3.2441
# Train(7)[50%]: Loss: 3.0653
# Train(7)[100%]: Loss: 3.0312
# Test(7): Loss: 3.0087, Accuracy: 6.4777%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.9836
# Train(8)[50%]: Loss: 2.9936
# Train(8)[100%]: Loss: 2.9921
# Test(8): Loss: 3.0035, Accuracy: 9.8516%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.9958
# Train(9)[50%]: Loss: 2.9869
# Train(9)[100%]: Loss: 2.9853
# Test(9): Loss: 2.9932, Accuracy: 15.2497%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 3.0058
# Train(10)[50%]: Loss: 2.9747
# Train(10)[100%]: Loss: 2.9720
# Test(10): Loss: 2.9754, Accuracy: 15.9244%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.9925
# Train(11)[50%]: Loss: 2.9657
# Train(11)[100%]: Loss: 2.9616
# Test(11): Loss: 2.9702, Accuracy: 17.2740%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.9578
# Train(12)[50%]: Loss: 2.9595
# Train(12)[100%]: Loss: 2.9573
# Test(12): Loss: 2.9670, Accuracy: 16.7341%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.9747
# Train(13)[50%]: Loss: 2.9560
# Train(13)[100%]: Loss: 2.9559
# Test(13): Loss: 2.9644, Accuracy: 17.0040%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.9725
# Train(14)[50%]: Loss: 2.9553
# Train(14)[100%]: Loss: 2.9525
# Test(14): Loss: 2.9579, Accuracy: 18.0837%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.9009
# Train(15)[50%]: Loss: 2.9545
# Train(15)[100%]: Loss: 2.9533
# Test(15): Loss: 2.9600, Accuracy: 17.8138%
# Optimizer Learning rate: 0.0000
# Cutoff Frequency is 1000.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 3.0622
# Train(1)[50%]: Loss: 3.0804
# Train(1)[100%]: Loss: 3.0733
# Test(1): Loss: 3.0034, Accuracy: 7.4224%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 2.7087
# Train(2)[50%]: Loss: 3.0721
# Train(2)[100%]: Loss: 3.0858
# Test(2): Loss: 3.0057, Accuracy: 5.3981%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 3.2603
# Train(3)[50%]: Loss: 3.0739
# Train(3)[100%]: Loss: 3.0824
# Test(3): Loss: 3.0054, Accuracy: 6.0729%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 3.2555
# Train(4)[50%]: Loss: 3.0775
# Train(4)[100%]: Loss: 3.0613
# Test(4): Loss: 3.0017, Accuracy: 6.2078%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 3.2449
# Train(5)[50%]: Loss: 3.0172
# Train(5)[100%]: Loss: 2.9906
# Test(5): Loss: 2.9281, Accuracy: 13.4953%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 2.6808
# Train(6)[50%]: Loss: 2.9347
# Train(6)[100%]: Loss: 2.9200
# Test(6): Loss: 2.8823, Accuracy: 18.8934%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 2.9162
# Train(7)[50%]: Loss: 2.8770
# Train(7)[100%]: Loss: 2.8763
# Test(7): Loss: 2.8538, Accuracy: 19.8381%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.9728
# Train(8)[50%]: Loss: 2.8585
# Train(8)[100%]: Loss: 2.8575
# Test(8): Loss: 2.8309, Accuracy: 21.0526%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.8248
# Train(9)[50%]: Loss: 2.8550
# Train(9)[100%]: Loss: 2.8445
# Test(9): Loss: 2.8343, Accuracy: 19.8381%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 2.9625
# Train(10)[50%]: Loss: 2.8363
# Train(10)[100%]: Loss: 2.8382
# Test(10): Loss: 2.8222, Accuracy: 19.7031%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.8809
# Train(11)[50%]: Loss: 2.8361
# Train(11)[100%]: Loss: 2.8322
# Test(11): Loss: 2.8149, Accuracy: 19.0283%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.9023
# Train(12)[50%]: Loss: 2.8224
# Train(12)[100%]: Loss: 2.8286
# Test(12): Loss: 2.8196, Accuracy: 19.7031%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.8660
# Train(13)[50%]: Loss: 2.8300
# Train(13)[100%]: Loss: 2.8285
# Test(13): Loss: 2.8202, Accuracy: 20.5128%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.7924
# Train(14)[50%]: Loss: 2.8357
# Train(14)[100%]: Loss: 2.8287
# Test(14): Loss: 2.8212, Accuracy: 20.5128%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.8979
# Train(15)[50%]: Loss: 2.8296
# Train(15)[100%]: Loss: 2.8261
# Test(15): Loss: 2.8200, Accuracy: 19.5682%
# Optimizer Learning rate: 0.0000
# Cutoff Frequency is 2000.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 3.0545
# Train(1)[50%]: Loss: 3.0741
# Train(1)[100%]: Loss: 3.0704
# Test(1): Loss: 2.9831, Accuracy: 7.9622%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 3.0600
# Train(2)[50%]: Loss: 3.0081
# Train(2)[100%]: Loss: 2.9988
# Test(2): Loss: 2.9545, Accuracy: 18.2186%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 2.9758
# Train(3)[50%]: Loss: 2.9150
# Train(3)[100%]: Loss: 2.8783
# Test(3): Loss: 2.8070, Accuracy: 20.7827%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 2.9340
# Train(4)[50%]: Loss: 2.8129
# Train(4)[100%]: Loss: 2.8000
# Test(4): Loss: 2.7542, Accuracy: 22.8070%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 2.7525
# Train(5)[50%]: Loss: 2.7718
# Train(5)[100%]: Loss: 2.7663
# Test(5): Loss: 2.7228, Accuracy: 24.6964%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 2.5769
# Train(6)[50%]: Loss: 2.7331
# Train(6)[100%]: Loss: 2.7295
# Test(6): Loss: 2.7233, Accuracy: 25.9109%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 2.8638
# Train(7)[50%]: Loss: 2.7060
# Train(7)[100%]: Loss: 2.7015
# Test(7): Loss: 2.7115, Accuracy: 24.6964%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.8394
# Train(8)[50%]: Loss: 2.6937
# Train(8)[100%]: Loss: 2.6929
# Test(8): Loss: 2.7037, Accuracy: 26.9906%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.5370
# Train(9)[50%]: Loss: 2.6996
# Train(9)[100%]: Loss: 2.6849
# Test(9): Loss: 2.7090, Accuracy: 25.3711%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 2.7682
# Train(10)[50%]: Loss: 2.6686
# Train(10)[100%]: Loss: 2.6760
# Test(10): Loss: 2.7025, Accuracy: 27.9352%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.8004
# Train(11)[50%]: Loss: 2.6673
# Train(11)[100%]: Loss: 2.6676
# Test(11): Loss: 2.6871, Accuracy: 26.9906%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.8117
# Train(12)[50%]: Loss: 2.6598
# Train(12)[100%]: Loss: 2.6744
# Test(12): Loss: 2.7096, Accuracy: 27.8003%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.5501
# Train(13)[50%]: Loss: 2.6588
# Train(13)[100%]: Loss: 2.6645
# Test(13): Loss: 2.6966, Accuracy: 27.6653%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.5850
# Train(14)[50%]: Loss: 2.6781
# Train(14)[100%]: Loss: 2.6751
# Test(14): Loss: 2.7051, Accuracy: 27.5304%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.8156
# Train(15)[50%]: Loss: 2.6670
# Train(15)[100%]: Loss: 2.6668
# Test(15): Loss: 2.7065, Accuracy: 26.9906%
# Optimizer Learning rate: 0.0000
# Cutoff Frequency is 4000.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 3.0547
# Train(1)[50%]: Loss: 3.0482
# Train(1)[100%]: Loss: 3.0194
# Test(1): Loss: 2.9635, Accuracy: 19.0283%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 2.9151
# Train(2)[50%]: Loss: 2.9038
# Train(2)[100%]: Loss: 2.8752
# Test(2): Loss: 2.7947, Accuracy: 20.5128%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 2.9256
# Train(3)[50%]: Loss: 2.7945
# Train(3)[100%]: Loss: 2.7701
# Test(3): Loss: 2.6660, Accuracy: 34.0081%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 2.6809
# Train(4)[50%]: Loss: 2.7056
# Train(4)[100%]: Loss: 2.6798
# Test(4): Loss: 2.5964, Accuracy: 41.0256%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 2.7041
# Train(5)[50%]: Loss: 2.6092
# Train(5)[100%]: Loss: 2.6138
# Test(5): Loss: 2.5560, Accuracy: 45.6140%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 2.3769
# Train(6)[50%]: Loss: 2.5839
# Train(6)[100%]: Loss: 2.5701
# Test(6): Loss: 2.5082, Accuracy: 49.2578%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 2.8572
# Train(7)[50%]: Loss: 2.5359
# Train(7)[100%]: Loss: 2.5327
# Test(7): Loss: 2.5138, Accuracy: 50.8772%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.7033
# Train(8)[50%]: Loss: 2.5329
# Train(8)[100%]: Loss: 2.5303
# Test(8): Loss: 2.5059, Accuracy: 53.9811%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.5017
# Train(9)[50%]: Loss: 2.5310
# Train(9)[100%]: Loss: 2.5205
# Test(9): Loss: 2.5089, Accuracy: 51.6869%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 2.5962
# Train(10)[50%]: Loss: 2.5065
# Train(10)[100%]: Loss: 2.5134
# Test(10): Loss: 2.4989, Accuracy: 55.3306%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.3811
# Train(11)[50%]: Loss: 2.5138
# Train(11)[100%]: Loss: 2.5092
# Test(11): Loss: 2.5047, Accuracy: 51.1471%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.7086
# Train(12)[50%]: Loss: 2.5053
# Train(12)[100%]: Loss: 2.5148
# Test(12): Loss: 2.5094, Accuracy: 52.9015%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.5524
# Train(13)[50%]: Loss: 2.5103
# Train(13)[100%]: Loss: 2.5110
# Test(13): Loss: 2.4864, Accuracy: 54.6559%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.3908
# Train(14)[50%]: Loss: 2.5271
# Train(14)[100%]: Loss: 2.5222
# Test(14): Loss: 2.4959, Accuracy: 55.7355%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.5042
# Train(15)[50%]: Loss: 2.5018
# Train(15)[100%]: Loss: 2.5106
# Test(15): Loss: 2.4855, Accuracy: 57.2200%
# Optimizer Learning rate: 0.0000
# Cutoff Frequency is 8000.
# Done with calculating spectrograms.
# Train(1)[0%]: Loss: 3.0183
# Train(1)[50%]: Loss: 3.0058
# Train(1)[100%]: Loss: 2.9730
# Test(1): Loss: 3.0268, Accuracy: 5.2632%
# Optimizer Learning rate: 0.0010
# Train(2)[0%]: Loss: 2.8441
# Train(2)[50%]: Loss: 2.8632
# Train(2)[100%]: Loss: 2.8427
# Test(2): Loss: 3.0494, Accuracy: 6.4777%
# Optimizer Learning rate: 0.0010
# Train(3)[0%]: Loss: 2.9265
# Train(3)[50%]: Loss: 2.7740
# Train(3)[100%]: Loss: 2.7568
# Test(3): Loss: 3.0575, Accuracy: 6.2078%
# Optimizer Learning rate: 0.0010
# Train(4)[0%]: Loss: 2.7133
# Train(4)[50%]: Loss: 2.7061
# Train(4)[100%]: Loss: 2.6848
# Test(4): Loss: 3.0488, Accuracy: 5.2632%
# Optimizer Learning rate: 0.0010
# Train(5)[0%]: Loss: 2.7173
# Train(5)[50%]: Loss: 2.6050
# Train(5)[100%]: Loss: 2.6001
# Test(5): Loss: 3.0610, Accuracy: 5.3981%
# Optimizer Learning rate: 0.0001
# Train(6)[0%]: Loss: 2.3684
# Train(6)[50%]: Loss: 2.5611
# Train(6)[100%]: Loss: 2.5508
# Test(6): Loss: 3.0553, Accuracy: 4.5884%
# Optimizer Learning rate: 0.0001
# Train(7)[0%]: Loss: 2.6553
# Train(7)[50%]: Loss: 2.5250
# Train(7)[100%]: Loss: 2.5175
# Test(7): Loss: 3.0557, Accuracy: 4.9933%
# Optimizer Learning rate: 0.0001
# Train(8)[0%]: Loss: 2.6007
# Train(8)[50%]: Loss: 2.5151
# Train(8)[100%]: Loss: 2.5120
# Test(8): Loss: 3.0623, Accuracy: 5.1282%
# Optimizer Learning rate: 0.0001
# Train(9)[0%]: Loss: 2.5011
# Train(9)[50%]: Loss: 2.5052
# Train(9)[100%]: Loss: 2.5002
# Test(9): Loss: 3.0567, Accuracy: 4.0486%
# Optimizer Learning rate: 0.0001
# Train(10)[0%]: Loss: 2.5741
# Train(10)[50%]: Loss: 2.4871
# Train(10)[100%]: Loss: 2.4998
# Test(10): Loss: 3.0559, Accuracy: 4.1835%
# Optimizer Learning rate: 0.0000
# Train(11)[0%]: Loss: 2.3399
# Train(11)[50%]: Loss: 2.5046
# Train(11)[100%]: Loss: 2.4993
# Test(11): Loss: 3.0593, Accuracy: 5.8030%
# Optimizer Learning rate: 0.0000
# Train(12)[0%]: Loss: 2.6559
# Train(12)[50%]: Loss: 2.4817
# Train(12)[100%]: Loss: 2.4992
# Test(12): Loss: 3.0595, Accuracy: 4.4534%
# Optimizer Learning rate: 0.0000
# Train(13)[0%]: Loss: 2.3958
# Train(13)[50%]: Loss: 2.4865
# Train(13)[100%]: Loss: 2.4928
# Test(13): Loss: 3.0703, Accuracy: 4.3185%
# Optimizer Learning rate: 0.0000
# Train(14)[0%]: Loss: 2.3923
# Train(14)[50%]: Loss: 2.5106
# Train(14)[100%]: Loss: 2.5071
# Test(14): Loss: 3.0491, Accuracy: 4.7233%
# Optimizer Learning rate: 0.0000
# Train(15)[0%]: Loss: 2.4020
# Train(15)[50%]: Loss: 2.4897
# Train(15)[100%]: Loss: 2.4955
# Test(15): Loss: 3.0600, Accuracy: 4.9933%
# Optimizer Learning rate: 0.0000

# %%
for i in range(len(performances)):
    plt.plot(performances[i])
plt.show
plt.title('Testing Accuracy for LPF Audio w/ Various Cutoff Frequencies')
plt.xlabel('Number of Epochs')
plt.ylabel('Testing Accuracy [%]')
plt.legend(['200Hz','500Hz','1000Hz','2000Hz','4000Hz','None'])
plt.grid(True)
